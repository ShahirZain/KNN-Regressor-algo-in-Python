# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split  
from sklearn.neighbors import KNeighborsRegressor
35
mainTable = pd.read_csv("periodic_table.csv",encoding='iso-8859-1', skiprows=[92,99,70,56,38])
SubTable = mainTable[['number','name','atomic_number','period']]
SubTable
# Out:
#      number          name  atomic_number  period
# 0         1      Hydrogen            1.0       1
# 1         2        Helium            NaN       1
# 2         3       Lithium            3.0       2
# 3         4     Beryllium            4.0       2
# 4         5         Boron            5.0       2
# 5         6        Carbon            6.0       2
# 6         7      Nitrogen            7.0       2
# 7         8        Oxygen            8.0       2
# 8         9      Fluorine            9.0       2
# 9        10          Neon           10.0       2
# 10       11        Sodium           11.0       3
# 11       12     Magnesium           12.0       3
# 12       13      Aluminum           13.0       3
# 13       14       Silicon           14.0       3
# 14       15    Phosphorus           15.0       3
# 15       16        Sulfur           16.0       3
# 16       17      Chlorine           17.0       3
# 17       18         Argon           18.0       3
# ...

# %%
X = SubTable.iloc[:, SubTable.columns != 'atomic_number'].values  
Y = SubTable.iloc[:,SubTable.columns == 'atomic_number']
X_train, X_test, y_train, y_test = train_test_split(X, Y, shuffle=True ,random_state=42)

# %%
neigh = KNeighborsRegressor(n_neighbors=4)
#neigh.fit(X, Y)
X
type(X[0][1])
# Out:
# str
